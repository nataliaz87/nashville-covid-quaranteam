# %%
import pandas as pd
import folium
import folium.plugins as MarkerCluster
import folium.plugins as FastMarkerCluster
from sqlalchemy import create_engine
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from credentials import user 
from credentials import server 
from credentials import password 
from credentials import user,password,server

# %% [markdown]
# import geopandas as gpd /
# import plotly.express as px

# %% [markdown]
# engine = create_engine("postgres+psycopg2://postgres:postgres@localhost:5432/lahman_baseball")

# %% [markdown]
# engine = "postgres+psycopg2://nss_user:nssAWS2020@nyt-covid-1.csdmctdmvs7t.us-east-1.rds.amazonaws.com:5432/covid_data"

# %%
engine= engine = ("postgres+psycopg2://"+user+":"+password+"@"+server+": 5432/covid_data")

# %%
counties_df = pd.read_sql("SELECT * FROM counties;", con=engine)
counties_df
# Out:
#               date      county       state   fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061      1       0
# 1       2020-01-22   Snohomish  Washington  53061      1       0
# 2       2020-01-23   Snohomish  Washington  53061      1       0
# 3       2020-01-24        Cook    Illinois  17031      1       0
# 4       2020-01-24   Snohomish  Washington  53061      1       0
# ...            ...         ...         ...    ...    ...     ...
# 738756  2020-11-16  Sweetwater     Wyoming  56037   1110       4
# 738757  2020-11-16       Teton     Wyoming  56039   1192       2
# 738758  2020-11-16       Uinta     Wyoming  56041    760       4
# 738759  2020-11-16    Washakie     Wyoming  56043    226       7
# 738760  2020-11-16      Weston     Wyoming  56045    338       0
#
# [738761 rows x 6 columns]

# %%
hubnash=pd.read_csv('../data/hub_nashville.csv')
# Out:
# /Users/JMO/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
hubnash
# Out:
#         Request #       Status                Request Type  \
# 0          113016       Closed   Trash, Recycling & Litter
# 1           53502       Closed         Property Violations
# 2          119344       Closed   Trash, Recycling & Litter
# 3          127752       Closed   Trash, Recycling & Litter
# 4          113477       Closed   Trash, Recycling & Litter
# ...           ...          ...                         ...
# 486491     367580  In Progress         Property Violations
# 486492     366411  In Progress  Streets, Roads & Sidewalks
# 486493     367152  In Progress  Streets, Roads & Sidewalks
# 486494     366495  In Progress  Streets, Roads & Sidewalks
# 486495     364806  In Progress  Streets, Roads & Sidewalks
#
#                           Subrequest Type  \
# 0                            Cart Service
# 1                   Residential Complaint
# 2                      Damage to Property
# 3            New Service/Activate Service
# ...

# %%
clusters=pd.read_csv('../data/clusters.csv')
clusters
# Out:
#                                  Cluster Name      Facility Type  \
# 0                          Vanderbilt Parties   Social Gathering
# 1                    Event at Clementine Hall   Social Gathering
# 2                           Religious Retreat   Social Gathering
# 3         The Health Center at Richland Place               LTCF
# 4       Trevecca Center for Rehab and Healing               LTCF
# ..                                        ...                ...
# 57                   One Stone Church Service             Church
# 58                               Miss Kelli's                Bar
# 59  Nashville Rescue Mission - Women's Campus  Congregate Living
# 60                      Link Systems Electric              Other
# 61                         Iron Tribe Belmont                Gym
#
#    Cluster Start Date  # Cases   Latitude  Longitude
# 0           3/11/2020       49  36.144703 -86.802655
# 1           3/14/2020       23  36.152444 -86.844583
# ...

# %% [markdown]
# df =[hubnash."Closed When Created",!= True]

# %%
hubnash_true=hubnash[(hubnash["Latitude"].notna())&(hubnash["Closed When Created"]==True)]

# %%
hubnash_true_null=hubnash[(hubnash["Latitude"].isna())&(hubnash["Closed When Created"]==True)]

# %%
hubnash_true.shape
# Out:
# (106622, 21)

# %%
hubnash_true_null.shape
# Out:
# (100086, 21)

# %%
hubnash_true_null.head(5)
# Out:
#      Request #  Status                            Request Type  \
# 23      399369  Closed  Resolved by hubNashville on First Call
# 27      398716  Closed  Resolved by hubNashville on First Call
# 94      399095  Closed  Resolved by hubNashville on First Call
# 102     355988  Closed  Resolved by hubNashville on First Call
# 115     398634  Closed  Resolved by hubNashville on First Call
#
#                             Subrequest Type  \
# 23   Resolved by hubNashville on First Call
# 27   Resolved by hubNashville on First Call
# 94   Resolved by hubNashville on First Call
# 102  Resolved by hubNashville on First Call
# 115  Resolved by hubNashville on First Call
#
#                  Additional Subrequest Type      Date / Time Opened  \
# 23   Resolved by hubNashville on First Call  06/24/2020 02:36:15 PM
# 27   Resolved by hubNashville on First Call  06/23/2020 05:21:23 PM
# 94   Resolved by hubNashville on First Call  06/23/2020 10:00:16 PM
# ...

# %%
hubnash_false=hubnash[(hubnash["Latitude"].notna())&(hubnash["Closed When Created"]==False)]
hubnash_false
# Out:
#         Request #       Status                Request Type  \
# 0          113016       Closed   Trash, Recycling & Litter
# 1           53502       Closed         Property Violations
# 3          127752       Closed   Trash, Recycling & Litter
# 5           49644       Closed         Property Violations
# 6          128356       Closed   Trash, Recycling & Litter
# ...           ...          ...                         ...
# 486491     367580  In Progress         Property Violations
# 486492     366411  In Progress  Streets, Roads & Sidewalks
# 486493     367152  In Progress  Streets, Roads & Sidewalks
# 486494     366495  In Progress  Streets, Roads & Sidewalks
# 486495     364806  In Progress  Streets, Roads & Sidewalks
#
#                      Subrequest Type              Additional Subrequest Type  \
# 0                       Cart Service      Trash - Request an Additional Cart
# 1              Residential Complaint                   Residential Complaint
# ...

# %%
cluster_hub_covid=hubnash_false.loc[hubnash_false['Subrequest Type'].isin(["COVID-19 Violations"])]
cluster_hub_covid
# Out:
#         Request #  Status Request Type      Subrequest Type  \
# 1548       444823  Closed     COVID-19  COVID-19 Violations
# 3385       479965  Closed     COVID-19  COVID-19 Violations
# 3666       392927  Closed     COVID-19  COVID-19 Violations
# 3850       444512  Closed     COVID-19  COVID-19 Violations
# 3882       444440  Closed     COVID-19  COVID-19 Violations
# ...           ...     ...          ...                  ...
# 486334     500977     New     COVID-19  COVID-19 Violations
# 486358     500968  Closed     COVID-19  COVID-19 Violations
# 486370     501064  Closed     COVID-19  COVID-19 Violations
# 486460     501127  Closed     COVID-19  COVID-19 Violations
# 486461     501337  Closed     COVID-19  COVID-19 Violations
#
#        Additional Subrequest Type      Date / Time Opened  \
# 1548          COVID-19 Violations  08/14/2020 02:38:00 AM
# 3385          COVID-19 Violations  10/13/2020 11:48:40 AM
# 3666          COVID-19 Violations  06/16/2020 12:35:20 AM
# ...

# %% [markdown]
# ## There are 11,608 covid violation calls

# %% [markdown]
# hub_covid['Date']=hub_covid['Date / Time Opened'].str.split(',').str[0]

# %%
cluster_hub_covid.dtypes
# Out:
# Request #                       int64
# Status                         object
# Request Type                   object
# Subrequest Type                object
# Additional Subrequest Type     object
# Date / Time Opened             object
# Date / Time Closed             object
# Request Origin                 object
# System of Origin ID            object
# Contact Type                   object
# Preferred Language            float64
# State Issue                      bool
# Parent Request                float64
# Closed When Created              bool
# Address                        object
# City                           object
# Council District              float64
# ZIP                            object
# Latitude                      float64
# Longitude                     float64
# Mapped Location                object
# dtype: object

# %%
cluster_hub_covid['Date / Time Opened'] = pd.to_datetime(cluster_hub_covid['Date / Time Opened']).dt.strftime('%-m/%-d/%Y')
# Out:
# /Users/JMO/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hub_covid

# %% [markdown]
# hub_covid['Date / Time Opened'].astype(integer)

# %% [markdown]
# hub_covid_tw=hub_covid['Date / Time Opened'] = pd.to_datetime(hub_covid['Date / Time Opened'], format=' m%d%y')

# %% [markdown]
# hub_covid_two=hub_covid['Date / Time Opened'] = pd.to_datetime(hub_covid['Date / Time Opened'])

# %% [markdown]
# formatted_df = hub_covid_tw["Date / Time Opened"].strftime("%m/%d/%y")

# %%
clusters=clusters.rename(columns={'Cluster Start Date':'Start Date','Latitude':'Latitude_a','Longitude':'Longitude_a'})
cluster_hub_covid=cluster_hub_covid.rename(columns={'Date / Time Opened':'Start Date','Latitude':'Latitude_a','Longitude':'Longitude_a'})

# %%
clusters
# Out:
#                                  Cluster Name      Facility Type  Start Date  \
# 0                          Vanderbilt Parties   Social Gathering   3/11/2020
# 1                    Event at Clementine Hall   Social Gathering   3/14/2020
# 2                           Religious Retreat   Social Gathering   3/25/2020
# 3         The Health Center at Richland Place               LTCF    4/3/2020
# 4       Trevecca Center for Rehab and Healing               LTCF    4/4/2020
# ..                                        ...                ...         ...
# 57                   One Stone Church Service             Church   9/22/2020
# 58                               Miss Kelli's                Bar   10/1/2020
# 59  Nashville Rescue Mission - Women's Campus  Congregate Living   10/1/2020
# 60                      Link Systems Electric              Other  10/16/2020
# 61                         Iron Tribe Belmont                Gym  10/20/2020
#
#     # Cases  Latitude_a  Longitude_a
# ...

# %%
hub_cluster=cluster_hub_covid = pd.merge(cluster_hub_covid,clusters,on=['Start Date','Latitude_a'],how='inner')

# %%
hub_cluster
# Out:
#         Request #  Status Request Type      Subrequest Type  \
# 0        339424.0  Closed     COVID-19  COVID-19 Violations
# 1        339243.0  Closed     COVID-19  COVID-19 Violations
# 2        339215.0  Closed     COVID-19  COVID-19 Violations
# 3        339245.0  Closed     COVID-19  COVID-19 Violations
# 4        339244.0  Closed     COVID-19  COVID-19 Violations
# ...           ...     ...          ...                  ...
# 425924   468792.0  Closed     COVID-19  COVID-19 Violations
# 425925   468810.0  Closed     COVID-19  COVID-19 Violations
# 425926        NaN     NaN          NaN                  NaN
# 425927        NaN     NaN          NaN                  NaN
# 425928        NaN     NaN          NaN                  NaN
#
#        Additional Subrequest Type Start Date      Date / Time Closed  \
# 0             COVID-19 Violations   4/4/2020  04/09/2020 02:20:19 PM
# 1             COVID-19 Violations   4/4/2020  04/08/2020 03:25:57 PM
# ...

# %%
hub_covid_5= hub_cluster[(hub_cluster["Status"].notna())&(hub_cluster["Request Type"]== True)]
hub_covid_5
# Out:
# Empty DataFrame
# Columns: [Request #, Status, Request Type, Subrequest Type, Additional Subrequest Type, Start Date, Date / Time Closed, Request Origin, System of Origin ID, Contact Type, Preferred Language, State Issue, Parent Request, Closed When Created, Address, City, Council District, ZIP, Latitude_x, Longitude_x, Mapped Location, Cluster Name_x, Facility Type_x, # Cases_x, Latitude_y, Longitude_y, Cluster Name_y, Facility Type_y, # Cases_y, Latitude_x, Longitude_x, Cluster Name_x, Facility Type_x, # Cases_x, Latitude_y, Longitude_y, Cluster Name_y, Facility Type_y, # Cases_y, Latitude_a, Longitude_a_x, Cluster Name_x, Facility Type_x, # Cases_x, Longitude_a_y, Cluster Name_y, Facility Type_y, # Cases_y, Longitude_a]
# Index: []
#
# [0 rows x 49 columns]

# %% [markdown]
# ## There were 10,477 calls in relation to the covid clusters, so about 1,131 calls were not from the covid clusters

# %% [markdown]
# hub_covid.nlargest(5,'# Cases_x')

# %%
hub_cluster=hub_cluster.drop_duplicates(subset=['Start Date'])

# %%
hub_covid_large=hub_cluster.nlargest(5,'# Cases')
hub_covid_large
# Out:
#       Request #  Status Request Type      Subrequest Type  \
# 124    339754.0  Closed     COVID-19  COVID-19 Violations
# 1450   355786.0  Closed     COVID-19  COVID-19 Violations
# 2235   353043.0  Closed     COVID-19  COVID-19 Violations
# 3187   437346.0  Closed     COVID-19  COVID-19 Violations
# 383    392252.0  Closed     COVID-19  COVID-19 Violations
#
#      Additional Subrequest Type Start Date      Date / Time Closed  \
# 124         COVID-19 Violations   4/6/2020  04/13/2020 01:30:08 PM
# 1450        COVID-19 Violations  4/30/2020  05/01/2020 02:31:08 PM
# 2235        COVID-19 Violations  4/27/2020  04/28/2020 05:38:39 PM
# 3187                        NaN   8/4/2020  08/10/2020 04:10:54 PM
# 383         COVID-19 Violations  6/15/2020  06/16/2020 03:46:02 PM
#
#               Request Origin System of Origin ID Contact Type  ...  \
# 124   hubNashville Community                 NaN          NaN  ...
# 1450  hubNashville Community                 NaN          NaN  ...
# ...

# %%
counties_df.head(3)
