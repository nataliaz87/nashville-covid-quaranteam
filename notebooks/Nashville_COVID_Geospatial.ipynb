# %% [markdown]
# Geospatial - COVID NASHVILLE

# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
df_violations = pd.read_csv(r"C:\Users\mkoiv\Documents\NSS_Data_Analytics\nashville-covid-quaranteam\data\hubNashville311.csv")
df_violations
# Out:
# C:\Users\mkoiv\anaconda3\envs\geospatial\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Request #  Status                            Request Type  \
# 0          353977  Closed                                COVID-19
# 1          367021  Closed  Resolved by hubNashville on First Call
# 2          419194  Closed              Streets, Roads & Sidewalks
# 3          366600  Closed  Resolved by hubNashville on First Call
# 4          408945  Closed  Resolved by hubNashville on First Call
# ...           ...     ...                                     ...
# 486491        163  Closed               Trash, Recycling & Litter
# 486492       3202  Closed              Streets, Roads & Sidewalks
# 486493       1237  Closed              Streets, Roads & Sidewalks
# 486494       1921  Closed              Streets, Roads & Sidewalks
# 486495       3287  Closed              Streets, Roads & Sidewalks
#
#                                           Subrequest Type  \
# 0       COVID-19 - Submit Input about The Plan to Reop...
# 1                  Resolved by hubNashville on First Call
# 2                                Remove debris in roadway
# 3                  Resolved by hubNashville on First Call
# 4                  Resolved by hubNashville on First Call
# ...                                                   ...
# 486491                 Missed Pickup - Trash Cart Service
# 486492                         Overgrowth on right of way
# 486493                         Overgrowth on right of way
# 486494                          Blocking the Right of Way
# 486495                       Driveway Transition/Drop Off
#
#                                Additional Subrequest Type  \
# 0       COVID-19 - Submit Input about The Plan to Reop...
# 1                  Resolved by hubNashville on First Call
# 2                                                 Roadway
# 3                  Resolved by hubNashville on First Call
# 4                  Resolved by hubNashville on First Call
# ...                                                   ...
# 486491               Trash - Curbside/Alley Missed Pickup
# 486492                                            Roadway
# 486493                                            Roadway
# 486494                          Blocking the Right of Way
# 486495                       Driveway Transition/Drop Off
#
#             Date / Time Opened      Date / Time Closed  \
# 0       04/28/2020 02:33:22 PM  04/28/2020 02:33:22 PM
# 1       05/13/2020 09:00:52 PM  05/13/2020 09:00:52 PM
# 2       07/17/2020 03:21:03 PM  07/28/2020 04:06:19 PM
# 3       05/13/2020 04:04:14 PM  05/13/2020 04:04:14 PM
# 4       07/06/2020 05:57:28 PM  07/06/2020 05:57:28 PM
# ...                        ...                     ...
# 486491  07/17/2017 07:12:00 AM  07/21/2017 11:58:00 AM
# 486492  07/28/2017 10:07:00 AM  08/15/2017 04:02:00 AM
# 486493  07/20/2017 07:44:00 AM  07/28/2017 04:22:00 PM
# 486494  07/22/2017 01:00:18 PM  07/23/2017 09:07:52 PM
# 486495  07/28/2017 06:11:29 PM  08/15/2017 09:02:35 AM
#
#                 Request Origin System of Origin ID Contact Type  ...  \
# 0       hubNashville Community                 NaN          NaN  ...
# 1                        Phone                 NaN          NaN  ...
# 2       hubNashville Community                 NaN          NaN  ...
# 3                        Phone                 NaN          NaN  ...
# 4                        Phone                 NaN          NaN  ...
# ...                        ...                 ...          ...  ...
# 486491                   Phone                 NaN          NaN  ...
# 486492                   Phone                 NaN          NaN  ...
# 486493                   Phone                 NaN          NaN  ...
# 486494                   Phone         OE-00020883          NaN  ...
# 486495                   Phone                 NaN          NaN  ...
#
#         State Issue  Parent Request  Closed When Created  \
# 0             False             NaN                 True
# 1             False             NaN                 True
# 2             False             NaN                False
# 3             False             NaN                 True
# 4             False             NaN                 True
# ...             ...             ...                  ...
# 486491        False             NaN                 True
# 486492        False             NaN                 True
# 486493        False             NaN                 True
# 486494        False             NaN                False
# 486495        False             NaN                False
#
#                              Address            City Council District    ZIP  \
# 0                                NaN             NaN              NaN    NaN
# 1                                NaN             NaN              NaN    NaN
# 2        Lafayette St & Claiborne St       NASHVILLE             17.0  37210
# 3                                NaN             NaN              NaN    NaN
# 4                                NaN             NaN              NaN    NaN
# ...                              ...             ...              ...    ...
# 486491           3117 PENN MEADE WAY       NASHVILLE             15.0  37214
# 486492      Cunniff Pkwy & Fonnic Dr  GOODLETTSVILLE              3.0  37072
# 486493     SHARPE AVE  & GRANADA AVE       NASHVILLE              5.0  37206
# 486494  MURFREESBORO PKE / DELL PKWY       NASHVILLE             13.0  37217
# 486495               338 LADYBIRD DR       NASHVILLE             28.0  37217
#
#          Latitude  Longitude              Mapped Location
# 0             NaN        NaN                          NaN
# 1             NaN        NaN                          NaN
# 2       36.148412 -86.761179     (36.1484116, -86.761179)
# 3             NaN        NaN                          NaN
# 4             NaN        NaN                          NaN
# ...           ...        ...                          ...
# 486491  36.242300 -86.704280         (36.2423, -86.70428)
# 486492  36.283740 -86.742120        (36.28374, -86.74212)
# 486493  36.189010 -86.753640        (36.18901, -86.75364)
# 486494  36.107803 -86.676879  (36.10780312, -86.67687864)
# 486495  36.097680 -86.664210        (36.09768, -86.66421)
#
# [486496 rows x 21 columns]

# %%
df_violations['ALI Latitude'] = df_violations['Latitude'].fillna(0)
df_violations['ALI Longitude'] = df_violations['Longitude'].fillna(0)
df_violations['LatLong'] = df_violations.apply(lambda row: [row['ALI Latitude'], row['ALI Longitude']], axis=1)

# %%
#replace Nan in ZIP, City column



df_violations['ZIP'] = df_violations['ZIP'].fillna(99999)
df_violations['City'] = df_violations['City'].fillna('Unknown')


# # # Set zipcode type to string (folium)
#df_violations['ZIP'] = df_violations['ZIP'].astype('str')
df_violations['City'] = df_violations['City'].astype('str')
#df_violations


# # get the mean value across all data points
zipcode_data = df_violations.groupby('ZIP').aggregate(np.mean)
zipcode_data

# zipcode_data.reset_index(inplace = True)

# zipcode_data['count'] = 1
# temp = zipcode_data.groupby(['ZIP','City']).sum()
# temp.reset_index(inplace = True)
# temp = temp[['ZIP', 'City','count']]
# zipcode_data = pd.merge(zipcode_data, temp, on='ZIP')

# zipcode_data.head(10)
# Out:
#              Request #  Preferred Language  State Issue  Parent Request  \
# ZIP
# 0.0      175992.521739                 NaN          0.0             NaN
# 37013.0  228550.493042                 NaN          0.0   282152.779376
# 37015.0  148787.043243                 NaN          0.0   158946.800000
# 37027.0  216819.674471                 NaN          0.0   219327.653846
# 37036.0  337135.000000                 NaN          0.0             NaN
# ...                ...                 ...          ...             ...
# 37232    337257.500000                 NaN          0.0             NaN
# 37240    302450.176471                 NaN          0.0             NaN
# 37246    370925.076923                 NaN          0.0             NaN
# 38011      6302.000000                 NaN          0.0             NaN
# TN       105884.333333                 NaN          0.0             NaN
#
#          Closed When Created  Council District   Latitude  Longitude  \
# ZIP
# 0.0                 0.478261         20.565217  36.152064 -86.790811
# 37013.0             0.316862         31.023713  36.057280 -86.641412
# 37015.0             0.205405          1.000000  36.244932 -86.943400
# 37027.0             0.288575          9.575672  36.037044 -86.762714
# 37036.0             0.000000               NaN  36.244619 -87.242157
# ...                      ...               ...        ...        ...
# 37232               0.000000         18.000000  36.143403 -86.800694
# 37240               0.352941         18.000000  36.148112 -86.803947
# 37246               0.384615         19.000000  36.158563 -86.790511
# 38011               0.000000               NaN        NaN        NaN
# TN                  0.333333               NaN  36.103293 -86.717257
#
#          ALI Latitude  ALI Longitude
# ZIP
# 0.0         36.152064     -86.790811
# 37013.0     36.011200     -86.530688
# 37015.0     35.853095     -86.003472
# 37027.0     36.026879     -86.738239
# 37036.0     36.244619     -87.242157
# ...               ...            ...
# 37232       36.143403     -86.800694
# 37240       36.148112     -86.803947
# 37246       36.158563     -86.790511
# 38011        0.000000       0.000000
# TN          12.034431     -28.905752
#
# [100 rows x 10 columns]
